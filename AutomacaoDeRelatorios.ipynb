# %%
# !pip install pyautogui
# !pip install pyperclip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pyautogui
import time
import pyperclip
import tkinter 
import subprocess

# %%
# Obtém a posição atual do mouse
time.sleep(4)
x, y = pyautogui.position()

# Exibe as coordenadas do mouse
print('Coordenadas do Mouse: ({}, {})'.format(x, y))
# Out:
# Coordenadas do Mouse: (1095, 465)

# %%
# Limpa a área de transferência
limpar_clipboard = subprocess.run("echo -n '' | xclip -selection clipboard", shell=True)

# Verifica se o comando foi executado com sucesso
if limpar_clipboard.returncode == 0:
    print("Área de transferência limpa com sucesso")
else:
    print("Erro ao limpar a área de transferência")

# Adiciona o texto desejado à área de transferência
adicionar_clipboard = subprocess.run("echo 'https://drive.google.com/drive/u/0/home' | xclip -selection clipboard", shell=True)

# Verifica se o comando foi executado com sucesso
if adicionar_clipboard.returncode == 0:
    print("Texto adicionado à área de transferência com sucesso")
else:
    print("Erro ao adicionar texto à área de transferência")

# Definindo o tempo de pausa global para 1 segundo
pyautogui.PAUSE = 0.02

# Abrindo uma nova aba no navegador
pyautogui.hotkey("ctrl", "t")
# Movendo o mouse para a posição (575, 89)
pyautogui.moveTo(575, 89)
# Clicando na posição (575, 89)
pyautogui.click(575, 89)
# Colando o texto da área de transferência
pyautogui.hotkey("ctrl", "v")
# Pressionando Enter para navegar até o link
pyautogui.press("enter")

# Espera o carregamento da página
time.sleep(6)

# Clicando para selecionar a opção desejada
pyautogui.moveTo(516, 184)
time.sleep(1)
pyautogui.click(516, 184)
# Escrevendo o texto "test_automation"
pyautogui.write("test_automation")
time.sleep(2)
# Pressionando Enter para navegar até o link
pyautogui.press("enter")
time.sleep(3)

# Clicando para selecionar a opção desejada
pyautogui.moveTo(1258, 401)
time.sleep(1)
pyautogui.click(1258, 401)
time.sleep(3)

# Clicando para selecionar a opção desejada
pyautogui.moveTo(1095, 465)
time.sleep(1)
pyautogui.click(1095, 465)

# Esperando o carregamento da página
time.sleep(7)

# Importando a biblioteca pandas
import pandas as pd

# Corrija o caminho do arquivo para apontar para o local correto no seu sistema
caminho_arquivo = "/home/user/Downloads/test_automation.xlsx"

# Lendo o arquivo Excel
tabela = pd.read_excel(caminho_arquivo)

# Exibindo a tabela
display(tabela)

# Calculando a soma da coluna "Valor Final"
faturamento = tabela["Valor Final"].sum()

# Calculando a soma da coluna "Quantidade"
quantidade = tabela["Quantidade"].sum()

# Imprimindo o faturamento e a quantidade
print(faturamento, quantidade)

# Limpa a área de transferência
limpar_clipboard = subprocess.run("echo -n '' | xclip -selection clipboard", shell=True)

# Adiciona o texto desejado à área de transferência
adicionar_clipboard = subprocess.run("echo 'https://mail.google.com/mail/u/0/#inbox' | xclip -selection clipboard", shell=True)

# Verifica se o comando foi executado com sucesso
if adicionar_clipboard.returncode == 0:
    print("Texto adicionado à área de transferência com sucesso")
else:
    print("Erro ao adicionar texto à área de transferência")

# Abrindo uma nova aba no navegador
pyautogui.hotkey("ctrl", "t")

# Esperando um tempo para o carregamento da página
time.sleep(4)

# Movendo o mouse para a posição (575, 89)
pyautogui.moveTo(575, 89)
# Clicando na posição (575, 89)
pyautogui.click(575, 89)
# Colando o texto da área de transferência
pyautogui.hotkey("ctrl", "v")
# Pressionando Enter para navegar até o link
pyautogui.press("enter")

# Esperando um tempo para o carregamento da página
time.sleep(5)

# Clicando para selecionar a opção desejada
pyautogui.moveTo(120, 248)
pyautogui.click(120, 248)

# Esperando um tempo para o carregamento da página
time.sleep(4)

# Clicando para selecionar a opção desejada
pyautogui.moveTo(938, 340)
pyautogui.click(938, 340)

# Limpa a área de transferência
limpar_clipboard = subprocess.run("echo -n '' | xclip -selection clipboard", shell=True)

# Adiciona o texto desejado à área de transferência
emailEnviarRelatorio = "tarcioapps7@gmail.com"  # Defina o valor da variável
adicionar_clipboard = subprocess.run(f"echo '{emailEnviarRelatorio}' | xclip -selection clipboard", shell=True)

# Verifica se o comando foi executado com sucesso
if adicionar_clipboard.returncode == 0:
    print("Texto adicionado à área de transferência com sucesso")
else:
    print("Erro ao adicionar texto à área de transferência")

# Colando o texto da área de transferência
pyautogui.hotkey("ctrl", "v")

time.sleep(4)

# Movendo o mouse para a posição (987, 396)
pyautogui.moveTo(892, 401)
# Clicando na posição (987, 396)
pyautogui.click(892, 401)

# Limpa a área de transferência
limpar_clipboard = subprocess.run("echo -n '' | xclip -selection clipboard", shell=True)

# Adiciona o texto desejado à área de transferência
AssuntoEmail = "Relatório Diário de Vendas"  # Defina o valor da variável
adicionar_clipboard = subprocess.run(f"echo '{AssuntoEmail}' | xclip -selection clipboard", shell=True)

# Verifica se o comando foi executado com sucesso
if adicionar_clipboard.returncode == 0:
    print("Texto adicionado à área de transferência com sucesso")
else:
    print("Erro ao adicionar texto à área de transferência")

# Colando o texto da área de transferência
pyautogui.hotkey("ctrl", "v")

# Definindo o texto do email
texto = f"""
Prezados, bom dia

O faturamento de ontem foi de: R${faturamento:,.2f}
A quantidade de produtos foi de: {quantidade:,}

Abs
Tarcio Teles"""

# Movendo o mouse para a posição (916, 473)
pyautogui.moveTo(916, 473)
# Clicando na posição (916, 473)
pyautogui.click(916, 473)

# Limpa a área de transferência
limpar_clipboard = subprocess.run("echo -n '' | xclip -selection clipboard", shell=True)

# Adiciona o texto desejado à área de transferência
adicionar_clipboard = subprocess.run(f"echo '{texto}' | xclip -selection clipboard", shell=True)

# Verifica se o comando foi executado com sucesso
if adicionar_clipboard.returncode == 0:
    print("Texto adicionado à área de transferência com sucesso")
else:
    print("Erro ao adicionar texto à área de transferência")
time.sleep(2)

# Colando o texto da área de transferência
pyautogui.hotkey("ctrl", "v")

# Movendo o mouse para a posição (804, 725)
pyautogui.moveTo(804, 725)
# Clicando na posição (804, 725)
pyautogui.click(804, 725)

# Importando a biblioteca os
import os

# Defina o caminho do arquivo que deseja excluir
caminho_arquivo = "/home/user/Downloads/test_automation.xlsx"

# Verifica se o arquivo existe antes de tentar excluir
if os.path.exists(caminho_arquivo):
    # Exclui o arquivo
    os.remove(caminho_arquivo)
    print(f"O arquivo {caminho_arquivo} foi excluído com sucesso.")
else:
    print(f"O arquivo {caminho_arquivo} não foi encontrado.")
# Out:
# Área de transferência limpa com sucesso
# Texto adicionado à área de transferência com sucesso
#          Nome  Quantidade  Valor Final
# 0   Produto A           2          300
# 1   Produto B           2          300
# 2   Produto C           2          300
# 3   Produto A           2          300
# 4   Produto B           2          300
# 5   Produto C           2          300
# 6   Produto A           2          300
# 7   Produto B           2          300
# 8   Produto C           2          300
# 9   Produto A           2          300
# 10  Produto B           2          300
# 11  Produto C           2          300
# 12  Produto A           2          300
# 13  Produto B           2          300
# 4200 28
# Texto adicionado à área de transferência com sucesso
# Texto adicionado à área de transferência com sucesso
# Texto adicionado à área de transferência com sucesso
# Texto adicionado à área de transferência com sucesso
# ...

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 4.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 4.5 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 KB 5.4 MB/s eta 0:00:000:00:01
# ...

# %%
# !pip install pyautogui
# !pip install pyperclip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# Obtém a posição atual do mouse
time.sleep(4)
x, y = pyautogui.position()

# Exibe as coordenadas do mouse
print('Coordenadas do Mouse: ({}, {})'.format(x, y))
# Out:
# Coordenadas do Mouse: (892, 401)
